# %%
# %pip install pymongo
from pymongo.mongo_client import MongoClient
import pandas as pd
import json
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
# uniform resource indentifier
uri = "mongodb+srv://vishal:vishal123@cluster0.tynyd.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri)

# %%
# create database name and collection name
DATABASE_NAME="WQI"
COLLECTION_NAME="Cluster0"

# %%
# read the data as a dataframe
df=pd.read_csv(r"C:\Users\hp\Documents\projects\ENDTOEND\upload_data_to_db\wqi_test (2).csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date   WQI
# 0           0  2023-01-01  75.9
# 1           1  2023-01-02  88.9
# 2           2  2023-01-03  89.5
# 3           3  2023-01-04  61.1
# 4           4  2023-01-05  66.2

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df
# Out:
#            Date   WQI
# 0    2023-01-01  75.9
# 1    2023-01-02  88.9
# 2    2023-01-03  89.5
# 3    2023-01-04  61.1
# 4    2023-01-05  66.2
# ..          ...   ...
# 360  2023-12-27  70.1
# 361  2023-12-28  60.7
# 362  2023-12-29  77.0
# 363  2023-12-30  73.2
# 364  2023-12-31  60.9
#
# [365 rows x 2 columns]

# %%
# Convert the data into json
json_record=list(json.loads(df.T.to_json()).values())

# %%
json_record
# Out:
# [{'Date': '2023-01-01', 'WQI': 75.9},
#  {'Date': '2023-01-02', 'WQI': 88.9},
#  {'Date': '2023-01-03', 'WQI': 89.5},
#  {'Date': '2023-01-04', 'WQI': 61.1},
#  {'Date': '2023-01-05', 'WQI': 66.2},
#  {'Date': '2023-01-06', 'WQI': 71.2},
#  {'Date': '2023-01-07', 'WQI': 52.2},
#  {'Date': '2023-01-08', 'WQI': 54.2},
#  {'Date': '2023-01-09', 'WQI': 69.4},
#  {'Date': '2023-01-10', 'WQI': 52.8},
#  {'Date': '2023-01-11', 'WQI': 76.7},
#  {'Date': '2023-01-12', 'WQI': 83.4},
#  {'Date': '2023-01-13', 'WQI': 55.6},
#  {'Date': '2023-01-14', 'WQI': 77.9},
#  {'Date': '2023-01-15', 'WQI': 74.4},
#  {'Date': '2023-01-16', 'WQI': 55.5},
#  {'Date': '2023-01-17', 'WQI': 84.1},
#  {'Date': '2023-01-18', 'WQI': 83.0},
#  {'Date': '2023-01-19', 'WQI': 79.5},
#  {'Date': '2023-01-20', 'WQI': 77.2},
#  {'Date': '2023-01-21', 'WQI': 77.0},
#  {'Date': '2023-01-22', 'WQI': 74.3},
#  {'Date': '2023-01-23', 'WQI': 57.8},
#  {'Date': '2023-01-24', 'WQI': 84.1},
#  {'Date': '2023-01-25', 'WQI': 86.7},
# ...

# %%
#now dump the data into the database
client[DATABASE_NAME][COLLECTION_NAME].insert_many(json_record)
# Out:
# InsertManyResult([ObjectId('67558aa1366f9b2688aa3868'), ObjectId('67558aa1366f9b2688aa3869'), ObjectId('67558aa1366f9b2688aa386a'), ObjectId('67558aa1366f9b2688aa386b'), ObjectId('67558aa1366f9b2688aa386c'), ObjectId('67558aa1366f9b2688aa386d'), ObjectId('67558aa1366f9b2688aa386e'), ObjectId('67558aa1366f9b2688aa386f'), ObjectId('67558aa1366f9b2688aa3870'), ObjectId('67558aa1366f9b2688aa3871'), ObjectId('67558aa1366f9b2688aa3872'), ObjectId('67558aa1366f9b2688aa3873'), ObjectId('67558aa1366f9b2688aa3874'), ObjectId('67558aa1366f9b2688aa3875'), ObjectId('67558aa1366f9b2688aa3876'), ObjectId('67558aa1366f9b2688aa3877'), ObjectId('67558aa1366f9b2688aa3878'), ObjectId('67558aa1366f9b2688aa3879'), ObjectId('67558aa1366f9b2688aa387a'), ObjectId('67558aa1366f9b2688aa387b'), ObjectId('67558aa1366f9b2688aa387c'), ObjectId('67558aa1366f9b2688aa387d'), ObjectId('67558aa1366f9b2688aa387e'), ObjectId('67558aa1366f9b2688aa387f'), ObjectId('67558aa1366f9b2688aa3880'), ObjectId('67558aa1366f9b2688aa
# ...
